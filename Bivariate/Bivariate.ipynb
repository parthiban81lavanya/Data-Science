# %%
#Covariance
import pandas as pd

# %%
dataset = pd.read_csv("PrePlacement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
df = pd.DataFrame(dataset)

# %%
#dataset.cov()
df.cov()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 #dataset.cov()
# ----> 2 df.cov()
#
# File C:\Anaconda\anaconda3\envs\v_env1\Lib\site-packages\pandas\core\frame.py:11204, in DataFrame.cov(self, min_periods, ddof, numeric_only)
#   11202 cols = data.columns
#   11203 idx = cols.copy()
# > 11204 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11206 if notna(mat).all():
#   11207     if min_periods is not None and min_periods > len(mat):
#
# File C:\Anaconda\anaconda3\envs\v_env1\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
dir(dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
import seaborn as sns
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
num_df = df.select_dtypes(include=['number'])

sns.heatmap(num_df.cov(), annot=True, cmap='coolwarm')
plt.title("Covariance Matrix (Numeric Only)")
plt.show()

sns.heatmap(num_df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Correlation Matrix (Numeric Only)")
plt.show()

# %%
#Covarience - differenc in 2 columns.  1) psotive , negative, zero
 #Corelation - Relation b/w 2 columns 1) dic propotional , inverse propotional, positive(1), negative(1-), high positive(), high negative, low positive, low negative.

# %%
def quanqual(dataset):
    quan=[]
    qual=[]
    for ColumnName in dataset.columns:
           # print(ColumnName)
            if (dataset[ColumnName].dtype=='O'):
#print("it is quantitative variable / column")   #numbers may be discrete or continous
                qual.append(ColumnName)
            else:
               # print("it is qualitative variable / column")      # Categorical data - nominal, or ordinal
                quan.append(ColumnName)
    return quan,qual

# %%
quan,qual = quanqual(dataset)

# %%
dataset[quan].cov()
# Out:
#                   ssc_p          hsc_p       degree_p        etest_p  \
# ssc_p        117.228377      58.853253      42.702550      37.659225
# hsc_p         58.853253     112.063731      33.684453      33.838355
# degree_p      42.702550      33.684453      53.604710      22.078774
# etest_p       37.659225      33.838355      22.078774     176.251018
# mba_p         24.535952      21.517688      17.185200      16.886973
# salary    908858.485818  731007.850848  466336.264888  372700.449468
#
#                   mba_p        salary
# ssc_p         24.535952  9.088585e+05
# hsc_p         21.517688  7.310079e+05
# degree_p      17.185200  4.663363e+05
# etest_p       16.886973  3.727004e+05
# mba_p         34.028376  1.239934e+05
# salary    123993.387361  2.259185e+10

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.090500 -0.091039  0.063636  0.022327  0.001217
# ssc_p    -0.078155  1.000000  0.513478  0.538686  0.261993  0.388478  0.558475
# hsc_p    -0.090500  0.513478  1.000000  0.434606  0.240775  0.348452  0.459424
# degree_p -0.091039  0.538686  0.434606  1.000000  0.227147  0.402376  0.423762
# etest_p   0.063636  0.261993  0.240775  0.227147  1.000000  0.218055  0.186775
# mba_p     0.022327  0.388478  0.348452  0.402376  0.218055  1.000000  0.141417
# salary    0.001217  0.558475  0.459424  0.423762  0.186775  0.141417  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
numeric_df = dataset[quan].select_dtypes(include=['number'])
cov_matrix = numeric_df.cov()
print(cov_matrix)
sns.heatmap(cov_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Covariance Matrix")
plt.show()
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -59.598879     -41.465047
# ssc_p       -52.641355     117.228377      58.853253      42.702550
# hsc_p       -59.598879      58.853253     112.063731      33.684453
# degree_p    -41.465047      42.702550      33.684453      53.604710
# etest_p      52.556168      37.659225      33.838355      22.078774
# mba_p         8.102336      24.535952      21.517688      17.185200
# salary    11383.177570  908858.485818  731007.850848  466336.264888
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  1.138318e+04
# ssc_p         37.659225      24.535952  9.088585e+05
# hsc_p         33.838355      21.517688  7.310079e+05
# degree_p      22.078774      17.185200  4.663363e+05
# etest_p      176.251018      16.886973  3.727004e+05
# mba_p         16.886973      34.028376  1.239934e+05
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
numeric_df = dataset[quan].select_dtypes(include=['number'])
corr_matrix = numeric_df.corr()
print(corr_matrix)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.513478  0.538686  0.261993  0.388478  0.558475
# hsc_p     0.513478  1.000000  0.434606  0.240775  0.348452  0.459424
# degree_p  0.538686  0.434606  1.000000  0.227147  0.402376  0.423762
# etest_p   0.261993  0.240775  0.227147  1.000000  0.218055  0.186775
# mba_p     0.388478  0.348452  0.402376  0.218055  1.000000  0.141417
# salary    0.558475  0.459424  0.423762  0.186775  0.141417  1.000000

# %%
#Multi colinearity should not be present in the data set. 
#Types : Structural Muti colinearity and Data Multi colinearity
# VARIENCE INFLATION FACTOR - VIF 
# VIF is to remove the muti colinearity in the dataset.

# %%
sns.pairplot(dataset) # Dataset with Serial number.

# %%
dataset.drop('sl_no',inplace=True,axis=1)

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
sns.pairplot(dataset) # Dataset without Serial number.

# %%
# Computes the Variance Inflation Factor (VIF) for each numeric column
#from statsmodels.stats.ouliers_influence import varience_inflation_factor

from statsmodels.stats.outliers_influence import variance_inflation_factor
def calculate_vif(x_input):
              
        vif_data = pd.DataFrame()
        vif_data["varibles"] = x_input.columns
        vif_data["VIF"] = [ 
            variance_inflation_factor(x_input.values, i ) 
            for i in range(x_input.shape[1])
        ] 
        return vif_data

# %%
#Assignment
#Takes a DataFrame from x_input.dataframe
#Adds a constant column
#Calculates Variance Inflation Factor (VIF) for each feature
#Returns a summary table showing which variables are multicollinear

# %%
quan,qual = quanqual(dataset)
calculate_vif(dataset[quan])
# Out:
#    varibles         VIF
# 0     ssc_p   78.168671
# 1     hsc_p   61.882196
# 2  degree_p  114.820554
# 3   etest_p   32.720365
# 4     mba_p  116.034378
# 5    salary    4.171783

# %%
calculate_vif(dataset[["etest_p","salary"]])
# Out:
#   varibles       VIF
# 0  etest_p  2.826904
# 1   salary  2.826904

# %%
# for the above we do not have much correlaton problem. We can create MODEL for these 2 columns.
#Assignment: Diff ways for muti colinearity

# %% [markdown]
# # T-Test

# %%
#Similarity between groups by mean
# G1 - Cold for 3 days and had natural medicine
#G2 - Cold for  5 days paramedical 5 days
# G3 - cold for 7 days Homoepathy

# Greater T test score similarity s less. lesser T value similarity is more.
# probablity low p value is good
#2 types  1) Independent T test (un-paired) , diff group same condition and 2) Dependent T test(paired ), same group diff condition

# %%
from scipy.stats import ttest_ind
dataset= dataset.dropna()
male_sal=dataset[dataset["gender"]=='M']["salary"]
female_sal=dataset[dataset["gender"]=='F']["salary"]
#print(female_sal)

# %%
female_sal
# Out:
# 6           0.0
# 12          0.0
# 13     218000.0
# 15     200000.0
# 17          0.0
#          ...
# 197    260000.0
# 198         0.0
# 204    210000.0
# 208         0.0
# 213    204000.0
# Name: salary, Length: 76, dtype: float64

# %%
male_sal
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           0.0
# 4      425000.0
#          ...
# 209    216000.0
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 214         0.0
# Name: salary, Length: 139, dtype: float64

# %%
dataset["gender"]=='M'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 210     True
# 211     True
# 212     True
# 213    False
# 214     True
# Name: gender, Length: 215, dtype: bool

# %%
Male_data= dataset[dataset["gender"]=='M']

# %%
Female_data =dataset[dataset["gender"]=='F']

# %%
Male_data
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 209      M  62.00  Central  72.00  Central  Commerce     65.00  Comm&Mgmt
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
Female_data
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 6        F  46.00   Others   49.2   Others  Commerce      79.0  Comm&Mgmt
# 12       F  47.00  Central   55.0   Others   Science      65.0  Comm&Mgmt
# 13       F  77.00  Central   87.0  Central  Commerce      59.0  Comm&Mgmt
# 15       F  65.00  Central   75.0  Central  Commerce      69.0  Comm&Mgmt
# 17       F  55.00  Central   67.0  Central  Commerce      64.0  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 197      F  83.96   Others   53.0   Others   Science      88.5   Sci&Tech
# 198      F  67.00  Central   70.0  Central  Commerce      65.0     Others
# 204      F  74.00   Others   73.0   Others  Commerce      73.0  Comm&Mgmt
# 208      F  43.00  Central   60.0   Others   Science      65.0  Comm&Mgmt
# 213      F  74.00   Others   66.0   Others  Commerce      58.0  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
ttest_ind(male_sal,female_sal)   #Diff grp same condition
# Out:
# TtestResult(statistic=2.0937842507001165, pvalue=0.03746230397067219, df=213.0)

# %%
from scipy.stats import ttest_ind
dataset= dataset.dropna()
c_board= dataset[dataset["ssc_b"]=='Central']["salary"]
s_board= dataset[dataset["ssc_b"]=='Others']["salary"]
ttest_ind(c_board,s_board)
# Out:
# TtestResult(statistic=-0.6182213205902315, pvalue=0.5370899470596882, df=213.0)

# %% [markdown]
# # Group is SAME  condition is Different
# # Dependent Paired T-test

# %%
from scipy.stats import ttest_ind
dataset= dataset.dropna()
male1_sal =dataset[dataset["gender"]=='M']["ssc_p"]
male2_sal =dataset[dataset["gender"]=='M']["hsc_p"]
ttest_ind(male1_sal,male2_sal)
# Out:
# TtestResult(statistic=0.4609004016724563, pvalue=0.6452330329980636, df=276.0)

# %%
from scipy.stats import ttest_ind
dataset= dataset.dropna()
f1_sal =dataset[dataset["gender"]=='F']["ssc_p"]
f2_sal =dataset[dataset["gender"]=='F']["hsc_p"]
ttest_ind(f1_sal,f2_sal)
# Out:
# TtestResult(statistic=0.9332471304863247, pvalue=0.3521921839567266, df=150.0)

# %% [markdown]
# # Different Group, same condition.
# # Independent Un-Paired T-test

# %%
#Assignment
#Grp = Commerce and  science , cond = MBA marks
from scipy.stats import ttest_ind
dataset= dataset.dropna()
c_mark =dataset[dataset["hsc_s"]=='Commerce']["mba_p"]
s_mark =dataset[dataset["hsc_s"]=='Science']["mba_p"]
ttest_ind(c_mark,s_mark)
# Out:
# TtestResult(statistic=-0.7331285580404581, pvalue=0.46432995253854314, df=202.0)

# %% [markdown]
# # Hypothesis Testing

# %%
# To test whether the UG - Commerce students and Science Students MBA marks are same ?
# Null Hypotheisis - There is a no similarity between the MBA marks of the commerce and science studuents
#

# %%
from scipy.stats import ttest_ind
dataset= dataset.dropna()
c_mark =dataset[dataset["hsc_s"]=='Commerce']["mba_p"]
s_mark =dataset[dataset["hsc_s"]=='Science']["mba_p"]
ttest_ind(c_mark,s_mark)
# Out:
# TtestResult(statistic=-0.7331285580404581, pvalue=0.46432995253854314, df=202.0)

# %%
#Either check the Static value of the P value. 
# If P value > 0.05 - Accept Null Hypothesis (H0) - 

# if P value < 0.05 - Accecpt Alternate Hypotesis (H1)- 


#Solution here is ACCECPT Null Hypothesis and REJECT Alternate Hypotesis

# %% [markdown]
# # ANAVO - Analysis of Varience

# %%
import scipy.stats as stats
#stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'],dataset['etest_p'])
stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'])
# Out:
# F_onewayResult(statistic=0.695991304348204, pvalue=0.4989557472581533)

# %%
#H0 - Null Hypothesis - there is no significant difference in the marks. 
#H1 -  Alternate  Hypothesis - there is significant difference in the marks. 
# P value is > 0.05 -Hence H0 Null Hypothesis is acceted.

# %%
#Calculate two way analysis"
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Example dataset
data = pd.DataFrame({
    'Marks': [70, 75, 80, 72, 78, 85, 90, 88, 92, 95, 99, 91],
    'Gender': ['M', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'M', 'M', 'F', 'F'],
    'Teaching_Method': ['A', 'A', 'B', 'B', 'A', 'A', 'B', 'B', 'A', 'B', 'A', 'B']
})

# Two-way ANOVA model
model = ols('Marks ~ C(Gender) + C(Teaching_Method) + C(Gender):C(Teaching_Method)', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                                   sum_sq   df         F    PR(>F)
# C(Gender)                     184.083333  1.0  1.907599  0.204580
# C(Teaching_Method)             24.083333  1.0  0.249568  0.630827
# C(Gender):C(Teaching_Method)    0.750000  1.0  0.007772  0.931917
# Residual                      772.000000  8.0       NaN       NaN

# %%
#Term	p-value	Interpretation
#C(Gender)	0.20	Since p > 0.05 → Gender has no significant effect on Marks
#C(Teaching_Method)	0.63	Teaching method also has no significant effect
#C(Gender):C(Teaching_Method)	0.93	No significant interaction effect between Gender and Method

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.graphics.factorplots import interaction_plot

fig = interaction_plot(data['Teaching_Method'], data['Gender'], data['Marks'],
                       colors=['red','blue'], markers=['D','^'], ms=10)
plt.title("Interaction Plot: Gender × Teaching Method")
plt.xlabel("Teaching Method")
plt.ylabel("Mean Marks")
plt.show()

# %%
# Assignment -2

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Example DataFrame
data = pd.DataFrame({
    'exercise_type': ['Aerobic', 'Aerobic', 'Strength', 'Strength', 'Aerobic', 'Strength'] * 10,
    'age_group': ['Teen', 'Adult', 'Senior', 'Teen', 'Adult', 'Senior'] * 10,
    'fitness_change': [4.2, 5.1, 3.5, 4.8, 5.0, 3.3] * 10
})

# Two-way ANOVA model
model = ols('fitness_change ~ C(exercise_type) + C(age_group) + C(exercise_type):C(age_group)', data=data).fit()

anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
#                                      sum_sq    df             F        PR(>F)
# C(exercise_type)               1.800532e-14   1.0  4.033192e-12  9.999984e-01
# C(age_group)                   2.016667e+00   2.0  2.258667e+02  2.631515e-21
# C(exercise_type):C(age_group)  2.902500e+01   2.0  3.250800e+03  1.203391e-58
# Residual                       2.500000e-01  56.0           NaN           NaN
# C:\Anaconda\anaconda3\envs\v_env1\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 1
#   warnings.warn('covariance of constraints does not have full '

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pointplot(x='age_group', y='fitness_change', hue='exercise_type', data=data, 
              capsize=0.1, errwidth=1.5, palette='Set2')
plt.title("Interaction between Exercise Type and Age Group on Fitness Change")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14896\3162380101.py:4: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 1.5}` instead.
#
#   sns.pointplot(x='age_group', y='fitness_change', hue='exercise_type', data=data,
